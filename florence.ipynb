# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import geopandas
import matplotlib.pyplot as plt

# %%
! cd /content/drive/MyDrive/githubrepos/geospatial-florence-project-root/geospatial-florence-project/data/ && ls
# Out:
# data_utils.py	       florence_2018.geojson  gz_2010_us_outline_500k.json
# florence_2018_data.py  florence_2018.json     gz_2010_us_outline_5m.json

# %%
country = geopandas.read_file("/content/drive/MyDrive/githubrepos/geospatial-florence-project-root/geospatial-florence-project/data/gz_2010_us_outline_5m.json")

# %%
country.head()
# Out:
#       TYPE R_STATEFP L_STATEFP  \
# 0  COASTAL                  02
# 1  COASTAL        02
# 2  COASTAL                  02
# 3  COASTAL                  02
# 4  COASTAL                  02
#
#                                             geometry
# 0  LINESTRING (-134.60836 58.17347, -134.60891 58...
# 1  LINESTRING (-135.70346 57.32204, -135.70292 57...
# 2  LINESTRING (-152.41742 57.81546, -152.42933 57...
# 3  LINESTRING (-158.04201 56.59674, -157.93399 56...
# 4  LINESTRING (-169.55394 56.60868, -169.61155 56...

# %%
country.plot()
# Out:
# <Axes: >

# %%
florence = geopandas.read_file("/content/drive/MyDrive/githubrepos/geospatial-florence-project-root/geospatial-florence-project/data/florence_2018.geojson")

# %%
florence.head()
# Out:
#   AdvisoryNumber              Date Wind  Pres               Movement  \
# 0              1  08/30/2018 11:00   30  1007  W at 12 MPH (280 deg)
# 1             1A  08/30/2018 14:00   30  1007  W at 12 MPH (280 deg)
# 2              2  08/30/2018 17:00   30  1007   W at 9 MPH (280 deg)
# 3             2A  08/30/2018 20:00   30  1007  W at 11 MPH (280 deg)
# 4              3  08/30/2018 23:00   35  1007  W at 13 MPH (280 deg)
#
#                          Type Name          Received Forecaster  \
# 0  Potential Tropical Cyclone  Six  08/30/2018 10:45      Avila
# 1  Potential Tropical Cyclone  Six  08/30/2018 13:36      Avila
# 2  Potential Tropical Cyclone  Six  08/30/2018 16:36      Avila
# 3  Potential Tropical Cyclone  Six  08/30/2018 19:44      Beven
# 4  Potential Tropical Cyclone  Six  08/30/2018 22:42      Beven
#
#             geometry
# 0  POINT (18.4 12.9)
# 1    POINT (19 12.9)
# 2  POINT (19.4 12.9)
# 3  POINT (20.4 13.1)
# 4  POINT (20.9 13.2)

# %%
type(florence.geometry)
# Out:
# geopandas.geoseries.GeoSeries

# %%
type(florence.geometry[0])
# Out:
# shapely.geometry.point.Point

# %%
florence.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   AdvisoryNumber  105 non-null    object
#  1   Date            105 non-null    object
#  2   Wind            105 non-null    object
#  3   Pres            105 non-null    object
#  4   Movement        105 non-null    object
#  5   Type            105 non-null    object
#  6   Name            105 non-null    object
#  7   Received        105 non-null    object
#  8   Forecaster      105 non-null    object
#  9   geometry        105 non-null    geometry
# dtypes: geometry(1), object(9)
# memory usage: 8.3+ KB

# %%
florence.plot()
# Out:
# <Axes: >

# %%
 # Plotting to see the hurricane overlay the US map:
fig, ax = plt.subplots(1, figsize=(30,20))
base = country.plot(ax=ax, color='#3B3C6E')

# plotting the hurricane position on top with red color to stand out:
florence.plot(ax=base, color='darkred', marker="*", markersize=10);
