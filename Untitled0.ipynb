# %%
# !ls
# Out:
# sample_data

# %%
# !cd /content/drive/MyDrive/githubrepos/geospatial-florence-project-root/ && ls
# Out:
# geospatial-florence-project

# %%
# !cd /content/drive/MyDrive/githubrepos/geospatial-florence-project-root/ && git config --global user.email "nyakudyamufa2002@gmail.com" && git config --global user.name "Mufaroconel"

# %%
# !cd /content/drive/MyDrive/githubrepos/geospatial-florence-project-root/geospatial-florence-project/ && git
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Untitled0.ipynb
# 	notebooks/Untitled
#
# nothing added to commit but untracked files present (use "git add" to track)
